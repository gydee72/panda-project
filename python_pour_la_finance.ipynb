# %% [markdown]
# <a href="https://colab.research.google.com/github/gydee72/agency/blob/main/python_pour_la_finance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd

# %%
apple = yf.download("AAPL", start = "2020-01-01", end = "2024-12-31")
# Out:
# /tmp/ipython-input-2-1755881062.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   apple = yf.download("AAPL", start = "2020-01-01", end = "2024-12-31")
# [*********************100%***********************]  1 of 1 completed

# %%
apple.head()
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02  72.620834  72.681281  71.373211  71.627084  135480400
# 2020-01-03  71.914810  72.676439  71.689950  71.847110  146322800
# 2020-01-06  72.487846  72.526533  70.783248  71.034709  118387200
# 2020-01-07  72.146942  72.753823  71.926915  72.497529  108872000
# 2020-01-08  73.307510  73.609745  71.849533  71.849533  132079200

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1257 entries, 2020-01-02 to 2024-12-30
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   1257 non-null   float64
#  1   (High, AAPL)    1257 non-null   float64
#  2   (Low, AAPL)     1257 non-null   float64
#  3   (Open, AAPL)    1257 non-null   float64
#  4   (Volume, AAPL)  1257 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.9 KB

# %%
apple.columns = apple.columns.droplevel("Ticker")

# %%
apple.head()
# Out:
# Price           Close       High        Low       Open     Volume
# Date
# 2020-01-02  72.620834  72.681281  71.373211  71.627084  135480400
# 2020-01-03  71.914810  72.676439  71.689950  71.847110  146322800
# 2020-01-06  72.487846  72.526533  70.783248  71.034709  118387200
# 2020-01-07  72.146942  72.753823  71.926915  72.497529  108872000
# 2020-01-08  73.307510  73.609745  71.849533  71.849533  132079200

# %%
print(apple.columns) #Afficher la colonne de dataframe
print(apple.index) #Affiche l'index du dataframe
print(apple.shape) #Affiche le nombre de ligne de la colonne du dataframe
print(apple.size) #affiche le nombre total d'élément dans le dataframe
# Out:
# Index(['Close', 'High', 'Low', 'Open', 'Volume'], dtype='object', name='Price')
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2024-12-16', '2024-12-17', '2024-12-18', '2024-12-19',
#                '2024-12-20', '2024-12-23', '2024-12-24', '2024-12-26',
#                '2024-12-27', '2024-12-30'],
#               dtype='datetime64[ns]', name='Date', length=1257, freq=None)
# (1257, 5)
# 6285

# %%
apple_tesla = yf.download(["AAPL","TSLA"], start = "2020-01-01", end = "2024-12-31", group_by = "Ticker")
apple_tesla.head()
# Out:
# /tmp/ipython-input-8-1279059152.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   apple_tesla = yf.download(["AAPL","TSLA"], start = "2020-01-01", end = "2024-12-31", group_by = "Ticker")
# [*********************100%***********************]  2 of 2 completed
# Ticker           AAPL                                                   TSLA  \
# Price            Open       High        Low      Close     Volume       Open
# Date
# 2020-01-02  71.627084  72.681281  71.373211  72.620834  135480400  28.299999
# 2020-01-03  71.847110  72.676439  71.689950  71.914810  146322800  29.366667
# 2020-01-06  71.034709  72.526533  70.783248  72.487846  118387200  29.364668
# 2020-01-07  72.497529  72.753823  71.926915  72.146942  108872000  30.760000
# 2020-01-08  71.849533  73.609745  71.849533  73.307510  132079200  31.580000
#
# Ticker
# Price            High        Low      Close     Volume
# Date
# 2020-01-02  28.713333  28.114000  28.684000  142981500
# ...

# %%
tsla = apple_tesla["TSLA"]
apple = apple_tesla["AAPL"]

# %%
apple.head()
# Out:
# Price            Open       High        Low      Close     Volume
# Date
# 2020-01-02  71.627084  72.681281  71.373211  72.620834  135480400
# 2020-01-03  71.847110  72.676439  71.689950  71.914810  146322800
# 2020-01-06  71.034709  72.526533  70.783248  72.487846  118387200
# 2020-01-07  72.497529  72.753823  71.926915  72.146942  108872000
# 2020-01-08  71.849533  73.609745  71.849533  73.307510  132079200

# %%
tsla.head()
# Out:
# Price            Open       High        Low      Close     Volume
# Date
# 2020-01-02  28.299999  28.713333  28.114000  28.684000  142981500
# 2020-01-03  29.366667  30.266666  29.128000  29.534000  266677500
# 2020-01-06  29.364668  30.104000  29.333332  30.102667  151995000
# 2020-01-07  30.760000  31.441999  30.224001  31.270666  268231500
# 2020-01-08  31.580000  33.232666  31.215334  32.809334  467164500
